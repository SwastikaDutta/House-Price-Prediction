# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('Kolkata_House_Price_Prediction_Updated.csv')

# %%
data_input = df[["Location","BHK", "Size (sqft)", "No. of Balconies", "No. of Bedrooms", "No. of Bathrooms",]]
data_output = df["Price (Lakh)"]

# %%
data.head(5)
# Out:
#      Location  BHK  Size (sqft)  No. of Balconies  Price (Lakh)  \
# 0  Tollygunge    3         2962                 1        351.49
# 1   Salt Lake    3         1684                 2        173.34
# 2       Garia    5         1463                 2        189.91
# 3      Howrah    5         2943                 1        502.98
# 4      Howrah    4         2306                 1        394.14
#
#    No. of Bedrooms  No. of Bathrooms
# 0                3                 3
# 1                3                 3
# 2                5                 4
# 3                5                 4
# 4                4                 3

# %%
data
# Out:
#        Location  BHK  Size (sqft)  No. of Balconies  Price (Lakh)  \
# 0    Tollygunge    3         2962                 1        351.49
# 1     Salt Lake    3         1684                 2        173.34
# 2         Garia    5         1463                 2        189.91
# 3        Howrah    5         2943                 1        502.98
# 4        Howrah    4         2306                 1        394.14
# ..          ...  ...          ...               ...           ...
# 995       Kasba    5         1288                 2        162.49
# 996    Jadavpur    1         2473                 2        346.99
# 997  Shyambazar    1         2916                 3        402.66
# 998       Garia    1         2628                 1        350.27
# 999   Salt Lake    1         2851                 2        288.01
#
#      No. of Bedrooms  No. of Bathrooms
# 0                  3                 3
# 1                  3                 3
# 2                  5                 4
# 3                  5                 4
# 4                  4                 3
# ..               ...               ...
# 995                5                 4
# 996                1                 1
# 997                1                 1
# 998                1                 1
# 999                1                 1
#
# [1000 rows x 7 columns]

# %%
data.dropna(inplace=True)

# %%
data
# Out:
#        Location  BHK  Size (sqft)  No. of Balconies  Price (Lakh)  \
# 0    Tollygunge    3         2962                 1        351.49
# 1     Salt Lake    3         1684                 2        173.34
# 2         Garia    5         1463                 2        189.91
# 3        Howrah    5         2943                 1        502.98
# 4        Howrah    4         2306                 1        394.14
# ..          ...  ...          ...               ...           ...
# 995       Kasba    5         1288                 2        162.49
# 996    Jadavpur    1         2473                 2        346.99
# 997  Shyambazar    1         2916                 3        402.66
# 998       Garia    1         2628                 1        350.27
# 999   Salt Lake    1         2851                 2        288.01
#
#      No. of Bedrooms  No. of Bathrooms
# 0                  3                 3
# 1                  3                 3
# 2                  5                 4
# 3                  5                 4
# 4                  4                 3
# ..               ...               ...
# 995                5                 4
# 996                1                 1
# 997                1                 1
# 998                1                 1
# 999                1                 1
#
# [1000 rows x 7 columns]

# %%
data.Location.value_counts()
# Out:
# Location
# Howrah         67
# Garia          64
# Kankurgachi    63
# Kasba          58
# Ballygunge     57
# Alipore        56
# Tollygunge     51
# Park Street    49
# Dum Dum        49
# Sealdah        49
# Lake Town      48
# Jadavpur       48
# Ultadanga      47
# New Town       46
# Salt Lake      45
# Baguiati       44
# Behala         43
# Rajarhat       42
# Shyambazar     40
# Barasat        34
# Name: count, dtype: int64

# %%
location_stats=data.groupby('Location')['Location'].agg('count')

# %%
location_stats
# Out:
# Location
# Alipore        56
# Baguiati       44
# Ballygunge     57
# Barasat        34
# Behala         43
# Dum Dum        49
# Garia          64
# Howrah         67
# Jadavpur       48
# Kankurgachi    63
# Kasba          58
# Lake Town      48
# New Town       46
# Park Street    49
# Rajarhat       42
# Salt Lake      45
# Sealdah        49
# Shyambazar     40
# Tollygunge     51
# Ultadanga      47
# Name: Location, dtype: int64

# %%
location_stats=data.groupby('Location')['Location'].agg('count').sort_values(ascending=False)

# %%
location_stats
# Out:
# Location
# Howrah         67
# Garia          64
# Kankurgachi    63
# Kasba          58
# Ballygunge     57
# Alipore        56
# Tollygunge     51
# Dum Dum        49
# Park Street    49
# Sealdah        49
# Jadavpur       48
# Lake Town      48
# Ultadanga      47
# New Town       46
# Salt Lake      45
# Baguiati       44
# Behala         43
# Rajarhat       42
# Shyambazar     40
# Barasat        34
# Name: Location, dtype: int64

# %%
locations_less_than_10_entries = location_stats[location_stats<=10]

# %%
locations_less_than_10_entries
# Out:
# Series([], Name: Location, dtype: int64)

# %%
data.describe()
# Out:
#                BHK  Size (sqft)  No. of Balconies  Price (Lakh)  \
# count  1000.000000  1000.000000       1000.000000   1000.000000
# mean      3.017000  1864.802000          2.084000    286.177500
# std       1.408792   687.820066          0.836447    153.515414
# min       1.000000   612.000000          1.000000     56.310000
# 25%       2.000000  1283.750000          1.000000    173.860000
# 50%       3.000000  1885.500000          2.000000    251.815000
# 75%       4.000000  2471.250000          3.000000    361.215000
# max       5.000000  2999.000000          3.000000    794.200000
#
#        No. of Bedrooms  No. of Bathrooms
# count      1000.000000       1000.000000
# mean          3.017000          2.617000
# std           1.408792          1.018503
# min           1.000000          1.000000
# 25%           2.000000          2.000000
# 50%           3.000000          3.000000
# 75%           4.000000          3.000000
# max           5.000000          4.000000

# %%
from sklearn.preprocessing import OneHotEncoder,StandardScaler

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.pipeline import make_pipeline

# %%
from sklearn.compose import make_column_transformer

# %%
col_trans=make_column_transformer((OneHotEncoder(sparse_output=False),['Location']),remainder='passthrough')

# %%
lr=LinearRegression()

# %%
scaler=StandardScaler()

# %%
model=make_pipeline(col_trans,scaler,lr)

# %%
x_train, x_test, y_train, y_test = train_test_split(data_input, data_output, test_size=0.2, random_state=42)

# %%
model.fit(x_train,y_train)
# Out:
# C:\Users\SWASTIKA\anaconda3\Lib\site-packages\sklearn\compose\_column_transformer.py:1623: FutureWarning:
# The format of the columns of the 'remainder' transformer in ColumnTransformer.transformers_ will change in version 1.7 to match the format of the other transformers.
# At the moment the remainder columns are stored as indices (of type int). With the same ColumnTransformer configuration, in the future they will be stored as column names (of type str).
# To use the new behavior now and suppress this warning, use ColumnTransformer(force_int_remainder_cols=False).
#
#   warnings.warn(
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(sparse_output=False),
#                                                   ['Location'])])),
#                 ('standardscaler', StandardScaler()),
#                 ('linearregression', LinearRegression())])

# %%
model.score(x_test,y_test)
# Out:
# 0.9438460875166046

# %%
input=pd.DataFrame([['Tollygunge',3,2000.0,2,2,3]],columns=['Location' ,'BHK','Size (sqft)','No. of Balconies','No. of Bedrooms','No. of Bathrooms'])

# %%
model.predict(input)
# Out:
# array([245.21567295])

# %%
import pickle as pk

# %%
pk.dump(model,open('House_prediction_model.pkl','wb'))

# %%
data.to_csv('Cleaned_data.csv')
